# %%
import pandas as pd
from pandas import datetime
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import seaborn as sns

# %%
def df_prep(datfram):
    datfram['date'] = datfram['YEAR'].astype(str) + '-' + datfram['MONTH'].astype(str) + '-1'
    
    for each in datfram.date:
        datetime.strptime(each, "%Y-%m-%d")
    
    datfram = datfram.drop(['DEPARTURES_SCHEDULED', 'DEPARTURES_PERFORMED', 'PAYLOAD', 'SEATS',
        'FREIGHT', 'MAIL', 'DISTANCE', 'RAMP_TO_RAMP', 'AIR_TIME',
       'UNIQUE_CARRIER', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
       'UNIQUE_CARRIER_ENTITY', 'REGION', 'CARRIER', 'CARRIER_NAME',
       'CARRIER_GROUP', 'CARRIER_GROUP_NEW', 'ORIGIN_AIRPORT_ID',
       'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
       'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS',
       'ORIGIN_STATE_NM', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
       'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME',
       'DEST_STATE_ABR', 'DEST_STATE_FIPS', 'DEST_STATE_NM', 'DEST_WAC',
       'AIRCRAFT_GROUP', 'AIRCRAFT_TYPE', 'AIRCRAFT_CONFIG', 'YEAR', 'QUARTER',
       'MONTH', 'DISTANCE_GROUP', 'CLASS', 'Unnamed: 45'], axis=1)
    
    # need to same it somewhere
    return datfram['PASSENGERS'].groupby(datfram['date']).sum()

# %% [markdown]
# # Create new dataframes that only contain the date and the number of passengers

# %%
df17 = pd.read_csv('2017.csv')

# %%
df_prep17 = df_prep(df17)
df_prep17_ = pd.DataFrame({'date':df_prep17.index, 'values':df_prep17.values})
# Out:
# date
# 2017-1-1    54910337.0
# 2017-2-1    51768122.0
# 2017-3-1    64826095.0
# 2017-4-1    61966814.0
# 2017-5-1    65361183.0
# 2017-6-1    67774037.0
# 2017-7-1    69659975.0
# 2017-8-1    67683949.0
# 2017-9-1    58012567.0
# Name: PASSENGERS, dtype: float64

# %%
df16 = pd.read_csv('2016.csv')

# %%
df_prep16 = df_prep(df16)
df_prep16_ = pd.DataFrame({'date':df_prep16.index, 'values':df_prep16.values})
# Out:
# date
# 2016-1-1     53273508.0
# 2016-10-1    62621299.0
# 2016-11-1    60147315.0
# 2016-12-1    60027468.0
# 2016-2-1     51801047.0
# 2016-3-1     62402015.0
# 2016-4-1     59733967.0
# 2016-5-1     63847204.0
# 2016-6-1     65750837.0
# 2016-7-1     67176775.0
# 2016-8-1     64615973.0
# 2016-9-1     59504895.0
# Name: PASSENGERS, dtype: float64

# %%
df15 = pd.read_csv('2015.csv')

# %%
df_prep15 = df_prep(df15)
df_prep15_ = pd.DataFrame({'date':df_prep15.index, 'values':df_prep15.values})

# %%
df14 = pd.read_csv('2014.csv')

# %%
df_prep14 = df_prep(df14)
df_prep14_ = pd.DataFrame({'date':df_prep14.index, 'values':df_prep14.values})

# %%
df13 = pd.read_csv('2013.csv')

# %%
df_prep13 = df_prep(df13)
df_prep13_ = pd.DataFrame({'date':df_prep13.index, 'values':df_prep13.values})

# %%
df12 = pd.read_csv('2012.csv')

# %%
df_prep12 = df_prep(df12)
df_prep12_ = pd.DataFrame({'date':df_prep12.index, 'values':df_prep12.values})

# %%
df11 = pd.read_csv('2011.csv')

# %%
df_prep11 = df_prep(df11)
df_prep11_ = pd.DataFrame({'date':df_prep11.index, 'values':df_prep11.values})

# %%
df10 = pd.read_csv('2010.csv')

# %%
df_prep10 = df_prep(df10)
df_prep10_ = pd.DataFrame({'date':df_prep10.index, 'values':df_prep10.values})

# %%
df9 = pd.read_csv('2009.csv')

# %%
df_prep9 = df_prep(df9)
df_prep9_ = pd.DataFrame({'date':df_prep9.index, 'values':df_prep9.values})

# %%
df8 = pd.read_csv('2008.csv')

# %%
df_prep8 = df_prep(df8)
df_prep8_ = pd.DataFrame({'date':df_prep8.index, 'values':df_prep8.values})

# %%
df7 = pd.read_csv('2007.csv')

# %%
df_prep7 = df_prep(df7)
df_prep7_ = pd.DataFrame({'date':df_prep7.index, 'values':df_prep7.values})

# %%
df6 = pd.read_csv('2006.csv')

# %%
df_prep6 = df_prep(df6)
df_prep6_ = pd.DataFrame({'date':df_prep6.index, 'values':df_prep6.values})

# %%
df5 = pd.read_csv('2005.csv')

# %%
df_prep5 = df_prep(df5)
df_prep5_ = pd.DataFrame({'date':df_prep5.index, 'values':df_prep5.values})

# %%
df4 = pd.read_csv('2004.csv')

# %%
df_prep4 = df_prep(df4)
df_prep4_ = pd.DataFrame({'date':df_prep4.index, 'values':df_prep4.values})

# %%
df3 = pd.read_csv('2003.csv')
# Out:
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_prep3 = df_prep(df3)
df_prep3_ = pd.DataFrame({'date':df_prep3.index, 'values':df_prep3.values})

# %%
df2 = pd.read_csv('2002.csv')

# %%
df_prep2 = df_prep(df2)
df_prep2_ = pd.DataFrame({'date':df_prep2.index, 'values':df_prep2.values})

# %%
df1 = pd.read_csv('2001.csv')

# %%
df_prep1 = df_prep(df1)
df_prep1_ = pd.DataFrame({'date':df_prep1.index, 'values':df_prep1.values})

# %%
df0 = pd.read_csv('2000.csv')

# %%
df_prep0 = df_prep(df0)
df_prep0_ = pd.DataFrame({'date':df_prep0.index, 'values':df_prep0.values})

# %%
df99 = pd.read_csv('1999.csv')

# %%
df_prep99 = df_prep(df99)
df_prep99_ = pd.DataFrame({'date':df_prep99.index, 'values':df_prep99.values})

# %%
df98 = pd.read_csv('1998.csv')

# %%
df_prep98 = df_prep(df98)
df_prep98_ = pd.DataFrame({'date':df_prep98.index, 'values':df_prep98.values})

# %% [markdown]
# # Concatanate all the newly created dataframes

# %%
frames = [df_prep17_, df_prep16_, df_prep15_, df_prep14_, df_prep13_, df_prep12_, df_prep11_, df_prep10_, 
         df_prep9_, df_prep8_, df_prep7_, df_prep6_, df_prep5_, df_prep4_, df_prep3_, df_prep2_, df_prep1_, 
         df_prep0_, df_prep99_, df_prep98_]

df = pd.concat(frames)

# %%
print(df.head())
print('\n Types Data: ')
print(df.dtypes)
# Out:
#        date      values
# 0  2017-1-1  54910337.0
# 1  2017-2-1  51768122.0
# 2  2017-3-1  64826095.0
# 3  2017-4-1  61966814.0
# 4  2017-5-1  65361183.0
#
#  Types Data:
# date       object
# values    float64
# dtype: object

# %%
df.index = pd.to_datetime(df.date)
df.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
df = df.reset_index(drop=True)

# %%
test_stationarity(df['values'])
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   """
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.333540
# p-value                          0.613692
# #Lags Used                      15.000000
# Number of Observations Used    221.000000
# Critical Value (1%)             -3.460291
# Critical Value (5%)             -2.874709
# Critical Value (10%)            -2.573789
# dtype: float64

# %%
#Estimating and eliminating trend: try log, square root, cube root, etc.

log_values = np.log(df['values'])
plt.plot(log_values)
plt.show()

# %%
# Moving Average

moving_avg = pd.rolling_mean(log_values,12)
plt.plot(log_values)
plt.plot(moving_avg, color='red')
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
log_values_moving_avg_diff = log_values - moving_avg

# %%
log_values_moving_avg_diff.dropna(inplace=True)
test_stationarity(log_values_moving_avg_diff)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   """
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.244186
# p-value                          0.190601
# #Lags Used                      11.000000
# Number of Observations Used    214.000000
# Critical Value (1%)             -3.461282
# Critical Value (5%)             -2.875143
# Critical Value (10%)            -2.574020
# dtype: float64

# %%
# exponentially weighted moving average
expwighted_avg = pd.ewma(log_values, halflife=12)
plt.plot(log_values)
plt.plot(expwighted_avg, color='red')
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(halflife=12,min_periods=0,adjust=True,ignore_na=False).mean()

# %%
log_values_ewma_diff = log_values - expwighted_avg
test_stationarity(log_values_ewma_diff)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   """
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.905622
# p-value                          0.329421
# #Lags Used                      13.000000
# Number of Observations Used    223.000000
# Critical Value (1%)             -3.460019
# Critical Value (5%)             -2.874590
# Critical Value (10%)            -2.573725
# dtype: float64

# %%
# Differencing

log_values_diff = log_values - log_values.shift()
plt.plot(log_values_diff)
plt.show()

# %%
log_values_diff.dropna(inplace=True)
test_stationarity(log_values_diff)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).mean()
#   """
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=12,center=False).std()
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.036971
# p-value                          0.001229
# #Lags Used                      15.000000
# Number of Observations Used    220.000000
# Critical Value (1%)             -3.460428
# Critical Value (5%)             -2.874769
# Critical Value (10%)            -2.573821
# dtype: float64

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(log_values_diff, nlags=20)
lag_pacf = pacf(log_values_diff, nlags=20, method='ols')

# %%
#Plot ACF:  
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(log_values_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(log_values_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.show()

# %%
#Plot PACF:
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(log_values_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(log_values_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(log_values, order=(1, 0, 1))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(log_values_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-log_values_diff)**2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py in _init_dates(self, dates, freq)
#      54                     if is_numeric_dtype(dates):
# ---> 55                         raise ValueError
#      56                     dates = to_datetime(dates)
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-399b5b3cea55> in <module>()
#       1 from statsmodels.tsa.arima_model import ARIMA
#       2
# ----> 3 model = ARIMA(log_values, order=(1, 0, 1))
#       4 results_ARIMA = model.fit(disp=-1)
#       5 plt.plot(log_values_diff)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
# ...

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(X)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-X)**2)/len(ts)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-ae41cb4d877d> in <module>()
# ----> 1 predictions_ARIMA = np.exp(predictions_ARIMA_log)
#       2 plt.plot(X)
#       3 plt.plot(predictions_ARIMA)
#       4 plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-X)**2)/len(ts)))
#
# NameError: name 'predictions_ARIMA_log' is not defined
